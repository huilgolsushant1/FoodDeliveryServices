# %% [markdown]
# # `01-import` Notebook
#
# Notebooks are numbered in the order they should be run (for data import projects) or according to a table of contents:
#
# * `00-setup` - initial environment setup and proof of concept
# * `01-import` - exploratory data analysis
#
#
# In this notebook we will use OSMNx and the Neo4j Python driver to import data from OpenStreetMap into Neo4j.
#
# ![](../img/data_model.png)

# %%
# Uncomment to install dependencies
# pip install neo4j
# pip install osmnx

# %%
import neo4j
import osmnx as ox
import networkx as nx

# %%
# Update with your Neo4j AuraDB credentials
NEO4J_URI = "neo4j://34.89.156.145:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "Star@123"

driver = neo4j.GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD), max_connection_lifetime=200)

# %% [markdown]
# ## OpenStreetMap Road Network With OSMNx

# %%
# Search OpenStreetMap and create a OSMNx graph

# G1 = ox.graph_from_place("San Mateo, CA, USA", network_type="bike")
G= ox.graph_from_place("San Mateo, CA, USA", network_type="drive")
# G3 = ox.graph_from_place("San Mateo, CA, USA", network_type="drive_service")
# G= nx.compose(G2, G3)
fig, ax = ox.plot_graph(G)

# %%
# Our road network graph can be represented as two GeoDataFrames

gdf_nodes, gdf_relationships = ox.graph_to_gdfs(G)
gdf_nodes.reset_index(inplace=True)
gdf_relationships.reset_index(inplace=True)

# %%
gdf_nodes.plot(markersize=0.1)
gdf_nodes
# Out:
#              osmid          y           x   ref            highway  \
# 0           281266  37.560184 -122.302578  414B  motorway_junction
# 1         26028129  37.481955 -122.177346   406  motorway_junction
# 2         26028133  37.483360 -122.180471   NaN                NaN
# 3         26029745  37.484536 -122.184170   NaN                NaN
# 4         26029880  37.541234 -122.284734  414A  motorway_junction
# ...            ...        ...         ...   ...                ...
# 18452  11829837291  37.545415 -122.304451   NaN                NaN
# 18453  11834834867  37.617608 -122.387253   NaN                NaN
# 18454  11834834868  37.617400 -122.387263   NaN                NaN
# 18455  11878873070  37.608975 -122.495644   NaN                NaN
# 18456  11880513057  37.478287 -122.190652   NaN                NaN
#
#        street_count                     geometry
# 0                 3  POINT (-122.30258 37.56018)
# 1                 3  POINT (-122.17735 37.48195)
# 2                 3  POINT (-122.18047 37.48336)
# 3                 3  POINT (-122.18417 37.48454)
# 4                 3  POINT (-122.28473 37.54123)
# ...             ...                          ...
# 18452             2  POINT (-122.30445 37.54541)
# 18453             3  POINT (-122.38725 37.61761)
# 18454             1  POINT (-122.38726 37.61740)
# 18455             4  POINT (-122.49564 37.60897)
# 18456             3  POINT (-122.19065 37.47829)
#
# [18457 rows x 7 columns]

# %%
gdf_relationships.plot(markersize=0.01, linewidth=0.5)
gdf_relationships
# Out:
#                  u           v  key  \
# 0           281266   702274215    0
# 1           281266    65358141    0
# 2         26028129    65388878    0
# 3         26028129    26028133    0
# 4         26028133    26029745    0
# ...            ...         ...  ...
# 46664  11878873070    65391007    0
# 46665  11878873070    65443756    0
# 46666  11880513057    65501171    0
# 46667  11880513057  4184236314    0
# 46668  11880513057    65492517    0
#
#                                             osmid  oneway         lanes  \
# 0                                        24054675    True             5
# 1                            [512386104, 8920615]    True             3
# 2      [385243928, 392651465, 679545026, 8924237]    True  [3, 4, 2, 1]
# 3                                       395436903    True             4
# 4                                       395436903    True             4
# ...                                           ...     ...           ...
# 46664                                     8929644   False           NaN
# 46665                                     8932826   False           NaN
# 46666                                    25795561   False           NaN
# 46667                    [1279812750, 1279812751]   False           NaN
# 46668                                  1279812754   False           NaN
#
#           ref                   name        highway maxspeed reversed  \
# 0      US 101       Bayshore Freeway       motorway   65 mph    False
# 1         NaN                    NaN  motorway_link   65 mph    False
# 2         NaN                    NaN  motorway_link   45 mph    False
# 3      US 101       Bayshore Freeway       motorway   65 mph    False
# 4      US 101       Bayshore Freeway       motorway   65 mph    False
# ...       ...                    ...            ...      ...      ...
# 46664     NaN        Old County Road    residential      NaN     True
# 46665     NaN  Rockaway Beach Avenue   unclassified      NaN     True
# 46666     NaN          Spring Street    residential      NaN     True
# 46667     NaN                    NaN    residential      NaN     True
# 46668     NaN          Spring Street    residential      NaN    False
#
#          length                                           geometry bridge  \
# 0      1327.761  LINESTRING (-122.30258 37.56018, -122.30222 37...    NaN
# 1       321.476  LINESTRING (-122.30258 37.56018, -122.30161 37...    NaN
# 2       377.868  LINESTRING (-122.17735 37.48195, -122.17752 37...    NaN
# 3       317.315  LINESTRING (-122.17735 37.48195, -122.17744 37...    NaN
# 4       351.773  LINESTRING (-122.18047 37.48336, -122.18184 37...    NaN
# ...         ...                                                ...    ...
# 46664   170.577  LINESTRING (-122.49564 37.60897, -122.49555 37...    NaN
# 46665    72.374  LINESTRING (-122.49564 37.60897, -122.49570 37...    NaN
# 46666   152.309  LINESTRING (-122.19065 37.47829, -122.19237 37...    NaN
# 46667    28.156  LINESTRING (-122.19065 37.47829, -122.19060 37...    NaN
# 46668    77.674  LINESTRING (-122.19065 37.47829, -122.19036 37...    NaN
#
#       junction access width tunnel
# 0          NaN    NaN   NaN    NaN
# 1          NaN    NaN   NaN    NaN
# 2          NaN    NaN   NaN    NaN
# 3          NaN    NaN   NaN    NaN
# 4          NaN    NaN   NaN    NaN
# ...        ...    ...   ...    ...
# 46664      NaN    NaN   NaN    NaN
# 46665      NaN    NaN   NaN    NaN
# 46666      NaN    NaN   NaN    NaN
# 46667      NaN    NaN   NaN    NaN
# 46668      NaN    NaN   NaN    NaN
#
# [46669 rows x 18 columns]

# %% [markdown]
# ## Neo4j Import

# %%
# First, define Cypher queries to create constraints and indexes

constraint_query = "CREATE CONSTRAINT IF NOT EXISTS FOR (i:Intersection) REQUIRE i.osmid IS UNIQUE"

rel_index_query = "CREATE INDEX IF NOT EXISTS FOR ()-[r:ROAD_SEGMENT]-() ON r.osmids"

address_constraint_query = "CREATE CONSTRAINT IF NOT EXISTS FOR (a:Address) REQUIRE a.id IS UNIQUE"

point_index_query = "CREATE POINT INDEX IF NOT EXISTS FOR (i:Intersection) ON i.location"

# Cypher query to import our road network nodes GeoDataFrame

node_query = '''
    UNWIND $rows AS row
    WITH row WHERE row.osmid IS NOT NULL
    MERGE (i:Intersection {osmid: row.osmid})
        SET i.location = 
         point({latitude: row.y, longitude: row.x }),
            i.ref = row.ref,
            i.highway = row.highway,
            i.street_count = toInteger(row.street_count)
    RETURN COUNT(*) as total
    '''

# Cypher query to import our road network relationships GeoDataFrame

rels_query = '''
    UNWIND $rows AS road
    MATCH (u:Intersection {osmid: road.u})
    MATCH (v:Intersection {osmid: road.v})
    MERGE (u)-[r:ROAD_SEGMENT {osmid: road.osmid}]->(v)
        SET r.oneway = road.oneway,
            r.lanes = road.lanes,
            r.ref = road.ref,
            r.name = road.name,
            r.highway = road.highway,
            r.max_speed = road.maxspeed,
            r.length = toFloat(road.length)
    RETURN COUNT(*) AS total
    '''

# %%
# Function to execute our constraint / index queries

def create_constraints(tx):
    results = tx.run(constraint_query)
    results = tx.run(rel_index_query)
    results = tx.run(address_constraint_query)
    results = tx.run(point_index_query)

# %%
# Function to batch our GeoDataFrames

def insert_data(tx, query, rows, batch_size=10000):
    total = 0
    batch = 0
    
    while batch * batch_size < len(rows):
        results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
        print(results)
        total += results[0]['total']
        batch += 1

# %%
# Run our constraints queries and nodes GeoDataFrame import

with driver.session() as session:
    session.execute_write(create_constraints)
    session.execute_write(insert_data, node_query, gdf_nodes.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 8457}]

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 6669}]

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %%
# Run our relationships GeoDataFrame import

with driver.session() as session:
    session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
# Out:
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 3900}]
# Transaction failed and will be retried in 0.8960437567357868s (There is not enough memory to perform the current task. Please try increasing 'server.memory.heap.max_size' in the neo4j configuration (normally in 'conf/neo4j.conf' or, if you are using Neo4j Desktop, found through the user interface) or if you are running an embedded installation increase the heap by using '-Xmx' command line flag, and then restart the database.)
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# [{'total': 10000}]
# ---------------------------------------------------------------------------
#
# TimeoutError                              Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#
#      49 while chunk_size == 0:
#
#      50     # Determine the chunk size and skip noop
#
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#
#      52     chunk_size = self._buffer.pop_u16()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#
#     325 while buffer.used < end:
#
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#
#     327     if n == 0:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#
#     492 def recv_into(self, buffer, nbytes):
#
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#
#     467 if self._deadline is None:
#
# --> 468     return func(*args, **kwargs)
#
#     469 timeout = self._socket.gettimeout()
#
#
#
# TimeoutError: timed out
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[29], line 4
#
#       3 with driver.session() as session:
#
# ----> 4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:757, in Session.execute_write(self, transaction_function, *args, **kwargs)
#
#     714 """Execute a unit of work in a managed write transaction.
#
#     715
#
#     716 .. note::
#
#    (...)
#
#     755 .. versionadded:: 5.0
#
#     756 """
#
# --> 757 return self._run_transaction(
#
#     758     WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#
#     759     transaction_function, args, kwargs
#
#     760 )
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:552, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#
#     551 try:
#
# --> 552     result = transaction_function(tx, *args, **kwargs)
#
#     553 except asyncio.CancelledError:
#
#     554     # if cancellation callback has not been called yet:
#
#
#
# Cell In[27], line 8, in insert_data(tx, query, rows, batch_size)
#
#       7 while batch * batch_size < len(rows):
#
# ----> 8     results = tx.run(query, parameters = {'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}).data()
#
#       9     print(results)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in Result.data(self, *keys)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:648, in <listcomp>(.0)
#
#     623 """Return the remainder of the result as a list of dictionaries.
#
#     624
#
#     625 Each dictionary represents a record
#
#    (...)
#
#     646     Can raise :exc:`.ResultConsumedError`.
#
#     647 """
#
# --> 648 return [record.data(*keys) for record in self]
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:68, in Inbox._buffer_one_chunk(self)
#
#      67 self._broken = True
#
# ---> 68 Util.callback(self.on_error, error)
#
#      69 raise
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:115, in Util.callback(cb, *args, **kwargs)
#
#     113     ...
#
# --> 115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:209, in TransactionBase._rollback(self)
#
#     205 if not (self._connection.defunct()
#
#     206         or self._connection.closed()
#
#     207         or self._connection.is_reset):
#
#     208     # DISCARD pending records then do a rollback.
#
# --> 209     self._consume_results()
#
#     210     self._connection.rollback(on_success=metadata.update)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:105, in TransactionBase._consume_results(self)
#
#     104 for result in self._results:
#
# --> 105     result._tx_end()
#
#     106 self._results = []
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:373, in Result._tx_end(self)
#
#     368 def _tx_end(self):
#
#     369     # Handle closure of the associated transaction.
#
#     370     #
#
#     371     # This will consume the result and mark it at out of scope.
#
#     372     # Subsequent calls to `next` will raise a ResultConsumedError.
#
# --> 373     self._exhaust()
#
#     374     self._out_of_scope = True
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:365, in Result._exhaust(self)
#
#     364 self._record_buffer.clear()
#
# --> 365 for _ in self:
#
#     366     pass
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\result.py:270, in Result.__iter__(self)
#
#     269 elif self._streaming:
#
# --> 270     self._connection.fetch_message()
#
#     271 elif self._discarding:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#
#     177 try:
#
# --> 178     func(*args, **kwargs)
#
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#
#
# AssertionError:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# AssertionError                            Traceback (most recent call last)
#
# Cell In[29], line 3
#
#       1 # Run our relationships GeoDataFrame import
#
# ----> 3 with driver.session() as session:
#
#       4     session.execute_write(insert_data, rels_query, gdf_relationships.drop(columns=['geometry'])) #FIXME: handle geometry
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:124, in Session.__exit__(self, exception_type, exception_value, traceback)
#
#     122         return
#
#     123     self._state_failed = True
#
# --> 124 self.close()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:207, in Session.close(self)
#
#     204 if self._transaction:
#
#     205     if self._transaction._closed() is False:
#
#     206         # roll back the transaction if it is not closed
#
# --> 207         self._transaction._rollback()
#
#     208     self._transaction = None
#
#     210 try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\transaction.py:218, in TransactionBase._rollback(self)
#
#     216 finally:
#
#     217     self._closed_flag = True
#
# --> 218     Util.callback(self._on_closed)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_async_compat\util.py:118, in Util.callback(cb, *args, **kwargs)
#
#     115 @staticmethod
#
#     116 def callback(cb, *args, **kwargs):
#
#     117     if callable(cb):
#
# --> 118         return cb(*args, **kwargs)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:400, in Session._transaction_closed_handler(self)
#
#     398 self._update_bookmark(self._transaction._bookmark)
#
#     399 self._transaction = None
#
# --> 400 self._disconnect()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\session.py:139, in Session._disconnect(self, sync)
#
#     137 def _disconnect(self, sync=False):
#
#     138     try:
#
# --> 139         return super()._disconnect(sync=sync)
#
#     140     except asyncio.CancelledError:
#
#     141         self._handle_cancellation(message="_disconnect")
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\work\workspace.py:190, in Workspace._disconnect(self, sync)
#
#     188         pass
#
#     189 if self._connection:
#
# --> 190     self._pool.release(self._connection)
#
#     191     self._connection = None
#
#     192 self._connection_access_mode = None
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#
#     367 try:
#
#     368     log.debug(
#
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#
#     370         connection.local_port, connection.connection_id
#
#     371     )
#
# --> 372     connection.reset()
#
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#
#     375               "on release: %r", connection.local_port, exc)
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#
#     320 self._append(b"\x0F", response=response,
#
#     321              dehydration_hooks=dehydration_hooks)
#
#     322 self.send_all()
#
# --> 323 self.fetch_all()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#
#     862 response = self.responses[0]
#
#     863 while not response.complete:
#
# --> 864     detail_delta, summary_delta = self.fetch_message()
#
#     865     detail_count += detail_delta
#
#     866     summary_count += summary_delta
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#
#     844     return 0, 0
#
#     846 # Receive exactly one message
#
# --> 847 tag, fields = self.inbox.pop(
#
#     848     hydration_hooks=self.responses[0].hydration_hooks
#
#     849 )
#
#     850 res = self._process_message(tag, fields)
#
#     851 self.idle_since = monotonic()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#
#      71 def pop(self, hydration_hooks):
#
# ---> 72     self._buffer_one_chunk()
#
#      73     try:
#
#      74         size, tag = self._unpacker.unpack_structure_header()
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\neo4j\_sync\io\_common.py:45, in Inbox._buffer_one_chunk(self)
#
#      44 def _buffer_one_chunk(self):
#
# ---> 45     assert not self._broken
#
#      46     try:
#
#      47         chunk_size = 0
#
#
#
# AssertionError:

# %% [markdown]
# ## Exploring The Road Network In Neo4j
#
# Now let's use Neo4j Bloom to visualize and explore our road network.
#
# ![](../img/BostonGraphViz.png)

# %% [markdown]
# # Adding Addresses
#
# We can use data from [OpenAddresses.io](https://openaddresses.io) to add addresses to our road network so that we can find routes between addresses.
#
# ![](../img/data_model_addresses.png)
#
# Data from OpenAddresses is GeoJSON that looks like this:
#
# ```
# {
#   "type":"Feature",
#   "properties":
#     {
#       "hash":"a98a4da3fa36d965",
#       "number":"599",
#       "street":"SKYLINE BLVD",
#       "unit":"",
#       "city":"DALY CITY",
#       "district":"",
#       "region":"",
#       "postcode":" ",
#       "id":"002011020"
#     },
#   "geometry":
#     { "type":"Point",
#       "coordinates":[-122.4995656,37.7033098]
#     }
# }
# ```

# %%
# We'll use apoc.load.json to import a JSON file of address data

add_addresses_query = """
CALL apoc.periodic.iterate(
  'CALL apoc.load.json("https://github.com/VindhyaKeshav/addresses/raw/main/source.geojson") YIELD value',
  'MERGE (a:Address {id: value.properties.id})
SET a.location = 
  point(
      {latitude: value.geometry.coordinates[1], longitude: value.geometry.coordinates[0]}),
    a.full_address = value.properties.number + " " + value.properties.street + " " + value.properties.city + ", CA " + value.properties.postcode

SET a += value.properties',
  {batchSize:10000, parallel:true})
"""

# Next, connect each address to the road network at the nearest intersection

near_intersection_query = """
CALL apoc.periodic.iterate(
  'MATCH (p:Address) WHERE NOT EXISTS ((p)-[:NEAREST_INTERSECTION]->(:Intersection)) RETURN p',
  'CALL {
  WITH p
  MATCH (i:Intersection)
  USING INDEX i:Intersection(location)
  WHERE point.distance(i.location, p.location) < 200

  WITH i
  ORDER BY point.distance(p.location, i.location) ASC 
  LIMIT 1
  RETURN i
}
WITH p, i

MERGE (p)-[r:NEAREST_INTERSECTION]->(i)
SET r.length = point.distance(p.location, i.location)
RETURN COUNT(p)',
  {batchSize:1000, parallel:false})
"""

# Create a full text index to enable search in our web app

full_text_query = "CREATE FULLTEXT INDEX search_index IF NOT EXISTS FOR (p:PointOfInterest|Address) ON EACH [p.name, p.full_address]"

# %%
# Transaction function to execute our address import queries

def enrich_addresses(tx):
    results = tx.run(add_addresses_query)        
    results = tx.run(near_intersection_query)

# %%
# Execute address import
with driver.session() as session:
    session.execute_write(enrich_addresses)

# %%
# Execute full text index query
with driver.session() as session:
    results = session.execute_write(lambda tx: tx.run(full_text_query))

# %% [markdown]
# ```
# MATCH (a:Address)-[:NEAREST_INTERSECTION]->(source:Intersection)
# WHERE a.full_address CONTAINS "410 E 5TH AVE SAN MATEO, CA"
# MATCH
#   (poi:Address)-[:NEAREST_INTERSECTION]->(dest:Intersection)
# WHERE poi.full_address CONTAINS "111 5TH AVE"
# CALL apoc.algo.dijkstra(source, dest, "ROAD_SEGMENT", "length")
# YIELD weight, path
# RETURN *
# //WITH [ x in nodes(path) | {latitude: x.location.latitude, longitude: x.location.longitude}] AS route, weight AS totalDist
# //RETURN *
# ```

# %% [markdown]
# ```
# CALL db.index.fulltext.queryNodes("search_index", $searchString)
# YIELD node, score
# RETURN coalesce(node.name, node.full_address) AS value, score, labels(node)[0] AS label, node.id AS id
# ORDER BY score DESC LIMIT 25
# ```
#
# ```
# MATCH (to {id: $dest})-[:NEAREST_INTERSECTION]->(source:Intersection)
# MATCH (from {id: $source})-[:NEAREST_INTERSECTION]->(target:Intersection)
# CALL apoc.algo.dijkstra(source, target, 'ROAD_SEGMENT', 'length')
# YIELD path, weight
# RETURN [n in nodes(path) | [n.location.latitude, n.location.longitude]] AS route
# ```
